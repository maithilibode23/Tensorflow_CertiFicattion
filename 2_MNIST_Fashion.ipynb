# %%
# !pip install -U tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (4.5.2)
# Requirement already satisfied: dataclasses in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.8)
# Requirement already satisfied: tqdm in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (4.64.1)
# Requirement already satisfied: promise in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: tensorflow-metadata in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.2.0)
# Requirement already satisfied: dill in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.3.4)
# Requirement already satisfied: absl-py in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (0.12.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (2.27.1)
# Requirement already satisfied: termcolor in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: protobuf>=3.12.2 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (3.19.6)
# Requirement already satisfied: numpy in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.19.5)
# Requirement already satisfied: typing-extensions in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (3.7.4.3)
# Requirement already satisfied: importlib-resources in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (5.4.0)
# Requirement already satisfied: six in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow_datasets) (1.16.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from requests>=2.19.0->tensorflow_datasets) (1.26.16)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from importlib-resources->tensorflow_datasets) (3.6.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tensorflow-metadata->tensorflow_datasets) (1.56.3)
# Requirement already satisfied: colorama in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from tqdm->tensorflow_datasets) (0.4.4)

# %%
from __future__ import absolute_import, division, print_function

# %%
# !pip install ipywidgets
import tensorflow as tf
import tensorflow_datasets as tfds
import math
import numpy as np
import matplotlib.pyplot as plt
# progress bar
import tqdm
import tqdm.auto
tqdm.tqdm = tqdm.auto.tqdm
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-7.8.1-py2.py3-none-any.whl (124 kB)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipywidgets) (0.2.0)
# Collecting jupyterlab-widgets<3,>=1.0.0
#   Downloading jupyterlab_widgets-1.1.7-py3-none-any.whl (295 kB)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipywidgets) (7.16.1)
# Collecting comm>=0.1.3
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Collecting widgetsnbextension~=3.6.6
#   Downloading widgetsnbextension-3.6.6-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipywidgets) (4.3.3)
# Requirement already satisfied: jedi>=0.10 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.17.0)
# Requirement already satisfied: pickleshare in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: backcall in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (58.0.4)
# Requirement already satisfied: decorator in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: pygments in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.11.2)
# Requirement already satisfied: parso>=0.7.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jedi>=0.10->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from traitlets>=4.3.1->ipywidgets) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (6.4.3)
# Requirement already satisfied: nbconvert in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.7)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.4)
# Requirement already satisfied: argon2-cffi in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (20.1.0)
# Requirement already satisfied: nbformat in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.1.3)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (22.2.1)
# Requirement already satisfied: ipykernel in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.3.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.1.2)
# Requirement already satisfied: jinja2 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.0.3)
# Requirement already satisfied: prometheus-client in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.13.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jupyter-client>=5.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (228)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: bleach in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.1.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: testpath in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.0)
# Requirement already satisfied: async-generator in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.10)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.0.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.4.0)
# Requirement already satisfied: webencodings in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Requirement already satisfied: packaging in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\maithili bode\.conda\envs\deepl\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.0.9)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets
# Successfully installed comm-0.1.4 ipywidgets-7.8.1 jupyterlab-widgets-1.1.7 widgetsnbextension-3.6.6

# %%
dataset, metadata = tfds.load('fashion_mnist',as_supervised=True,with_info=True)

# %%
train_dataset,test_dataset = dataset['train'],dataset['test']

# %%
train_dataset
# Out:
# <PrefetchDataset shapes: ((28, 28, 1), ()), types: (tf.uint8, tf.int64)>

# %%
type(train_dataset)
# Out:
# tensorflow.python.data.ops.dataset_ops.PrefetchDataset

# %%
class_names = ['T-shirt/Top','Trouser','Pullover','Dress','Coat','Sandal','Shirt',
              'Sneaker','Bag','Ankel_boot']

# %%
class_names
# Out:
# ['T-shirt/Top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankel_boot']

# %%
num_training_examples = metadata.splits['train'].num_examples
num_testing_examples = metadata.splits['test'].num_examples

# %%
num_testing_examples
# Out:
# 10000

# %%
num_training_examples
# Out:
# 60000

# %%
print("Numbers of training Examples: {}".format(num_training_examples))
print("Numbers of testing Examples: {}".format(num_testing_examples))
# Out:
# Numbers of training Examples: 60000
# Numbers of testing Examples: 10000

# %%
def normalize(images,labels):
    images = tf.cast(images,tf.float32)
    images /= 255
    return images,labels

# %%
train_dataset = train_dataset.map(normalize)
test_dataset = test_dataset.map(normalize)

# %%
for image,label in test_dataset.take(1):
    break
image = image.numpy().reshape((28,28))
plt.figure()
plt.imshow(image,cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
i = 0
for (image,label) in test_dataset.take(25):
    image = image.numpy().reshape((28,28))
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image,cmap=plt.cm.binary)
    plt.xlabel(class_names[label])
    i+=1
plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(128,activation=tf.nn.relu),
    tf.keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
BATCH_SIZE = 32

# %%
train_dataset = train_dataset.repeat().shuffle(num_training_examples).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %%
model.fit(train_dataset,epochs=5,steps_per_epoch=math.ceil(num_training_examples/BATCH_SIZE))
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 10s 4ms/step - loss: 0.4938 - accuracy: 0.8239
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3727 - accuracy: 0.8656
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3359 - accuracy: 0.8769
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3132 - accuracy: 0.8849
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2899 - accuracy: 0.8925

# %%
test_loss, test_accuracy = model.evaluate(test_dataset,steps=math.ceil(num_testing_examples/BATCH_SIZE))
# Out:
# 313/313 [==============================] - 2s 3ms/step - loss: 0.3453 - accuracy: 0.8772

# %%
for test_images,test_labels in test_dataset.take(1):
    test_images = test_images.numpy()
    test_labels = test_labels.numpy()
    predictions = model.predict(test_images)

# %%
predictions.shape
# Out:
# (32, 10)

# %%
predictions[0]
# Out:
# array([1.6879949e-05, 2.4913672e-06, 2.9764678e-02, 3.4124535e-06,
#        9.2936200e-01, 7.1056858e-09, 4.0805679e-02, 1.6723678e-08,
#        4.4830438e-05, 8.6153210e-11], dtype=float32)

# %%
np.argmax(predictions[0])
# Out:
# 4

# %%
test_labels[0]
# Out:
# 4

# %%
def plot_image(i,predictions_array, true_labels,images):
    predictions_array,true_labels,img = predictions_array[i],true_labels[i],images[i]
    plt.grid(False)
    plt.yticks([])
    plt.xticks([])
    plt.imshow(img[...,0],cmap=plt.cm.binary)
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_labels:
        color = 'blue'
    else:
        color = 'red'
    plt.xlabel('{} {:2.0f}% ({})'.format(class_names[predicted_label],100*np.max(predictions_array),class_names[true_labels]),color=color)

# %%
def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array[i], true_label[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1]) 
  predicted_label = np.argmax(predictions_array)
  
  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i,predictions,test_labels,test_images)
plt.subplot(1,2,2)
plot_value_array(i,predictions,test_labels)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols,2*num_rows))
for i in range(num_images):
    plt.subplot(num_rows,2*num_cols,2*i+1)
    plot_image(i,predictions,test_labels,test_images)
    plt.subplot(num_rows,2*num_cols,2*i+2)
    plot_value_array(i,predictions,test_labels)

# %%
img = test_images[0]
print(img.shape)
# Out:
# (28, 28, 1)

# %%
img = np.array([img])
print(img.shape)
# Out:
# (1, 28, 28, 1)

# %%
prediction_single = model.predict(img)
print(prediction_single)
# Out:
# [[1.6879965e-05 2.4913695e-06 2.9764673e-02 3.4124503e-06 9.2936200e-01
#   7.1057129e-09 4.0805656e-02 1.6723712e-08 4.4830478e-05 8.6153050e-11]]

# %%
plot_value_array(0,prediction_single,test_labels)
_ = plt.xticks(range(10),class_names,rotation=45)
